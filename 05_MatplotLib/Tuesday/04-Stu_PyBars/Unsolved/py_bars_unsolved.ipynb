# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities,color='r',alpha=0.5,align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
ticks_cities = [value for value in x_axis]
plt.xticks(ticks_cities,["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcde2d56c40>,
# ...
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(7,9)
# Out:
# (7.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Bar per household statistics based on US cities")
plt.xlabel("Cities")
plt.ylabel("Bars per household")
# Out:
# Text(33.722222222222214, 0.5, 'Bars per household')

# %%
# Save an image of the chart and print it to the screen
plt.savefig('bars_per_household.jpg')
plt.show()
